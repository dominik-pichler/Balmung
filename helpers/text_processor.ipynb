# %%
import spacy
import neuralcoref
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import spacy
# ----> 2 import neuralcoref
#
# ModuleNotFoundError: No module named 'neuralcoref'

# %%
# !pip install --upgrade pip
# !pip install discord


# !pip install neuralcoref
# Out:
# Requirement already satisfied: pip in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/15/aa/3f4c7bcee2057a76562a5b33ecbd199be08cdb4443a02e26bd2c3cf6fc39/pip-23.3.2-py3-none-any.whl.metadata
#   Downloading pip-23.3.2-py3-none-any.whl.metadata (3.5 kB)
# Using cached pip-23.3.2-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-23.3.2
# Collecting discord
#   Downloading discord-2.3.2-py3-none-any.whl.metadata (381 bytes)
# Collecting discord.py>=2.3.2 (from discord)
#   Downloading discord.py-2.3.2-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from discord.py>=2.3.2->discord) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.2.0)
# Requirement already satisfied: idna>=2.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (3.4)
# Downloading discord-2.3.2-py3-none-any.whl (1.1 kB)
# Downloading discord.py-2.3.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.4 MB/s eta 0:00:000:00:010:00:01:01
# Installing collected packages: discord.py, discord
# Successfully installed discord-2.3.2 discord.py-2.3.2
# Collecting neuralcoref
#   Using cached neuralcoref-4.0.tar.gz (368 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.15.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from neuralcoref) (1.24.3)
# Collecting boto3 (from neuralcoref)
#   Using cached boto3-1.34.32-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from neuralcoref) (2.31.0)
# Requirement already satisfied: spacy>=2.1.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from neuralcoref) (3.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2023.7.22)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (3.1.2)
# Requirement already satisfied: setuptools in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from spacy>=2.1.0->neuralcoref) (3.3.0)
# Collecting botocore<1.35.0,>=1.34.32 (from boto3->neuralcoref)
#   Using cached botocore-1.34.32-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from boto3->neuralcoref) (0.10.0)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->neuralcoref)
#   Using cached s3transfer-0.10.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.32->boto3->neuralcoref) (2.8.2)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->neuralcoref)
#   Using cached urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->neuralcoref) (4.7.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.1.0->neuralcoref) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.1.0->neuralcoref) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy>=2.1.0->neuralcoref) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy>=2.1.0->neuralcoref) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from jinja2->spacy>=2.1.0->neuralcoref) (2.1.1)
# Requirement already satisfied: six>=1.5 in /Users/dominikpichler/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.32->boto3->neuralcoref) (1.16.0)
# Using cached boto3-1.34.32-py3-none-any.whl (139 kB)
# Using cached botocore-1.34.32-py3-none-any.whl (11.9 MB)
# Using cached s3transfer-0.10.0-py3-none-any.whl (82 kB)
# Using cached urllib3-2.0.7-py3-none-any.whl (124 kB)
# Building wheels for collected packages: neuralcoref
#   Building wheel for neuralcoref (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [42 lines of output]
#       /Users/dominikpichler/anaconda3/lib/python3.11/site-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-311
#       creating build/lib.macosx-11.1-arm64-cpython-311/neuralcoref
#       copying neuralcoref/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref
#       copying neuralcoref/file_utils.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref
#       creating build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/tests
#       copying neuralcoref/tests/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/tests
#       copying neuralcoref/tests/test_neuralcoref.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/tests
#       creating build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/algorithm.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/conllparser.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/compat.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/model.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/dataset.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/utils.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/document.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/learn.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       copying neuralcoref/train/evaluator.py -> build/lib.macosx-11.1-arm64-cpython-311/neuralcoref/train
#       running build_ext
#       building 'neuralcoref.neuralcoref' extension
#       creating build/temp.macosx-11.1-arm64-cpython-311
#       creating build/temp.macosx-11.1-arm64-cpython-311/neuralcoref
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/dominikpichler/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/dominikpichler/anaconda3/include -arch arm64 -I/Users/dominikpichler/anaconda3/include/python3.11 -I/private/var/folders/d2/jkwt52_n7kv66n_lj3trvtxw0000gn/T/pip-install-x23zbnfu/neuralcoref_63f7bead77d245e5b63384f05bbcd602/include -I/Users/dominikpichler/anaconda3/include/python3.11 -c neuralcoref/neuralcoref.cpp -o build/temp.macosx-11.1-arm64-cpython-311/neuralcoref/neuralcoref.o -O2 -Wno-strict-prototypes -Wno-unused-function
#       neuralcoref/neuralcoref.cpp:196:12: fatal error: 'longintrepr.h' file not found
#         #include "longintrepr.h"
#                  ^~~~~~~~~~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for neuralcoref
#   Running setup.py clean for neuralcoref
# Failed to build neuralcoref
# ERROR: Could not build wheels for neuralcoref, which is required to install pyproject.toml-based projects

# %%
import urllib.request
from bs4 import BeautifulSoup
import spacy
import neuralcoref
nlp = spacy.load('en_core_web_lg')
neuralcoref.add_to_pipe(nlp)

html = urllib.request.urlopen('https://www.law.cornell.edu/supremecourt/text/418/683').read()
soup = BeautifulSoup(html, 'html.parser')
text = ''.join([t for t in soup.find_all(text=True) if t.parent.name == 'p' and len(t) >= 25])
doc = nlp(text)
resolved_text = doc._.coref_resolved
sentences = [sent.string.strip() for sent in nlp(resolved_text).sents]
output = [sent for sent in sentences if 'president' in 
          (' '.join([token.lemma_.lower() for token in nlp(sent)]))]
print('Fact count:', len(output))
for fact in range(len(output)):
    print(str(fact+1)+'.', output[fact])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/dominikpichler/Documents/Pet_Projects/Athene/helpers/text_processor.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell:/Users/dominikpichler/Documents/Pet_Projects/Athene/helpers/text_processor.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> from bs4 import BeautifulSoup
#       <a href='vscode-notebook-cell:/Users/dominikpichler/Documents/Pet_Projects/Athene/helpers/text_processor.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> import spacy
# ----> <a href='vscode-notebook-cell:/Users/dominikpichler/Documents/Pet_Projects/Athene/helpers/text_processor.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> import neuralcoref
#       <a href='vscode-notebook-cell:/Users/dominikpichler/Documents/Pet_Projects/Athene/helpers/text_processor.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> nlp = spacy.load('en_core_web_lg')
#       <a href='vscode-notebook-cell:/Users/dominikpichler/Documents/Pet_Projects/Athene/helpers/text_processor.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> neuralcoref.add_to_pipe(nlp)
#
# ModuleNotFoundError: No module named 'neuralcoref'
