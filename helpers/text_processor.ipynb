# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
file_path =  '../resources/raw_input_data/The_critique_of_pure_reason.txt'


f = open(file_path,"r")
text = f.read()
print(text)
# Out:
# At first, her government, under the administration of the _dogmatists_,
# was an absolute _despotism_. But, as the legislative continued to show
# traces of the ancient barbaric rule, her empire gradually broke up, and
# intestine wars introduced the reign of _anarchy;_ while the _sceptics_,
# like nomadic tribes, who hate a permanent habitation and settled mode
# of living, attacked from time to time those who had organized
# themselves into civil communities. But their number was, very happily,
# small; and thus they could not entirely put a stop to the exertions of
# those who persisted in raising new edifices, although on no settled or
# uniform plan. In recent times the hope dawned upon us of seeing those
# disputes settled, and the legitimacy of her claims established by a
# kind of _physiology_ of the human understanding—that of the celebrated
# Locke. But it was found that—although it was affirmed that this
# so-called queen could not refer her descent to any higher source than
# that of common experience, a circumstance which necessarily brought
# suspicion on her claims—as this _genealogy_ was incorrect, she
# persisted in the advancement of her claims to sovereignty. Thus
# metaphysics necessarily fell back into the antiquated and rotten
# constitution of _dogmatism_, and again became obnoxious to the contempt
# from which efforts had been made to save it. At present, as all
# methods, according to the general persuasion, have been tried in vain,
# there reigns nought but weariness and complete _indifferentism_—the
# mother of chaos and night in the scientific world, but at the same time
# the source of, or at least the prelude to, the re-creation and
# reinstallation of a science, when it has fallen into confusion,
# obscurity, and disuse from ill directed effort.
#
# For it is in reality vain to profess _indifference_ in regard to such
# inquiries, the object of which cannot be indifferent to humanity.
# Besides, these pretended _indifferentists_, however much they may try
# to disguise themselves by the assumption of a popular style and by
# changes on the language of the schools, unavoidably fall into
# metaphysical declarations and propositions, which they profess to
# regard with so much contempt. At the same time, this indifference,
# which has arisen in the world of science, and which relates to that
# kind of knowledge which we should wish to see destroyed the last, is a
# phenomenon that well deserves our attention and reflection. It is
# plainly not the effect of the levity, but of the matured _judgement_[1]
# of the age, which refuses to be any longer entertained with illusory
# knowledge, It is, in fact, a call to reason, again to undertake the
# most laborious of all tasks—that of self-examination, and to establish
# a tribunal, which may secure it in its well-grounded claims, while it
# pronounces against all baseless assumptions and pretensions, not in an
# arbitrary manner, but according to its own eternal and unchangeable
# laws. This tribunal is nothing less than the _Critical Investigation of
# Pure Reason_.

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(text)
sent
# Out:
# [('At', 'IN'),
#  ('first', 'JJ'),
#  (',', ','),
#  ('her', 'PRP$'),
#  ('government', 'NN'),
#  (',', ','),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('administration', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('_dogmatists_', 'NNP'),
#  (',', ','),
#  ('was', 'VBD'),
#  ('an', 'DT'),
#  ('absolute', 'JJ'),
#  ('_despotism_', 'NN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  (',', ','),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('legislative', 'JJ'),
#  ('continued', 'NN'),
#  ('to', 'TO'),
#  ('show', 'VB'),
#  ('traces', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('ancient', 'NN'),
#  ('barbaric', 'NN'),
#  ('rule', 'NN'),
#  (',', ','),
#  ('her', 'PRP$'),
#  ('empire', 'NN'),
#  ('gradually', 'RB'),
#  ('broke', 'VBD'),
#  ('up', 'RP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('intestine', 'NN'),
#  ('wars', 'NNS'),
#  ('introduced', 'VBD'),
#  ('the', 'DT'),
#  ('reign', 'NN'),
#  ('of', 'IN'),
#  ('_anarchy', 'NN'),
#  (';', ':'),
#  ('_', 'CC'),
#  ('while', 'IN'),
#  ('the', 'DT'),
#  ('_sceptics_', 'NNP'),
#  (',', ','),
#  ('like', 'IN'),
#  ('nomadic', 'JJ'),
#  ('tribes', 'NNS'),
#  (',', ','),
#  ('who', 'WP'),
#  ('hate', 'VBP'),
#  ('a', 'DT'),
#  ('permanent', 'JJ'),
#  ('habitation', 'NN'),
#  ('and', 'CC'),
#  ('settled', 'VBD'),
#  ('mode', 'NN'),
#  ('of', 'IN'),
#  ('living', 'NN'),
#  (',', ','),
#  ('attacked', 'VBN'),
#  ('from', 'IN'),
#  ('time', 'NN'),
#  ('to', 'TO'),
#  ('time', 'NN'),
#  ('those', 'DT'),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('organized', 'VBN'),
#  ('themselves', 'PRP'),
#  ('into', 'IN'),
#  ('civil', 'JJ'),
#  ('communities', 'NNS'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('their', 'PRP$'),
#  ('number', 'NN'),
#  ('was', 'VBD'),
#  (',', ','),
#  ('very', 'RB'),
#  ('happily', 'RB'),
#  (',', ','),
#  ('small', 'JJ'),
#  (';', ':'),
#  ('and', 'CC'),
#  ('thus', 'RB'),
#  ('they', 'PRP'),
#  ('could', 'MD'),
#  ('not', 'RB'),
#  ('entirely', 'RB'),
#  ('put', 'VB'),
#  ('a', 'DT'),
#  ('stop', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('exertions', 'NNS'),
#  ('of', 'IN'),
#  ('those', 'DT'),
#  ('who', 'WP'),
#  ('persisted', 'VBD'),
#  ('in', 'IN'),
#  ('raising', 'VBG'),
#  ('new', 'JJ'),
#  ('edifices', 'NNS'),
#  (',', ','),
#  ('although', 'IN'),
#  ('on', 'IN'),
#  ('no', 'DT'),
#  ('settled', 'VBN'),
#  ('or', 'CC'),
#  ('uniform', 'JJ'),
#  ('plan', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('recent', 'JJ'),
#  ('times', 'NNS'),
#  ('the', 'DT'),
#  ('hope', 'NN'),
#  ('dawned', 'VBD'),
#  ('upon', 'IN'),
#  ('us', 'PRP'),
#  ('of', 'IN'),
#  ('seeing', 'VBG'),
#  ('those', 'DT'),
#  ('disputes', 'NNS'),
#  ('settled', 'VBD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('legitimacy', 'NN'),
#  ('of', 'IN'),
#  ('her', 'PRP$'),
#  ('claims', 'NNS'),
#  ('established', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('kind', 'NN'),
#  ('of', 'IN'),
#  ('_physiology_', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('human', 'JJ'),
#  ('understanding—that', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('celebrated', 'JJ'),
#  ('Locke', 'NNP'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('found', 'VBN'),
#  ('that—although', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('affirmed', 'VBN'),
#  ('that', 'IN'),
#  ('this', 'DT'),
#  ('so-called', 'JJ'),
#  ('queen', 'NN'),
#  ('could', 'MD'),
#  ('not', 'RB'),
#  ('refer', 'VB'),
#  ('her', 'PRP$'),
#  ('descent', 'NN'),
#  ('to', 'TO'),
#  ('any', 'DT'),
#  ('higher', 'JJR'),
#  ('source', 'NN'),
#  ('than', 'IN'),
#  ('that', 'DT'),
#  ('of', 'IN'),
#  ('common', 'JJ'),
#  ('experience', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('circumstance', 'NN'),
#  ('which', 'WDT'),
#  ('necessarily', 'RB'),
#  ('brought', 'VBD'),
#  ('suspicion', 'NN'),
#  ('on', 'IN'),
#  ('her', 'PRP$'),
#  ('claims—as', 'NN'),
#  ('this', 'DT'),
#  ('_genealogy_', 'NN'),
#  ('was', 'VBD'),
#  ('incorrect', 'JJ'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('persisted', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('advancement', 'NN'),
#  ('of', 'IN'),
#  ('her', 'PRP$'),
#  ('claims', 'NNS'),
#  ('to', 'TO'),
#  ('sovereignty', 'VB'),
#  ('.', '.'),
#  ('Thus', 'NNP'),
#  ('metaphysics', 'NNS'),
#  ('necessarily', 'RB'),
#  ('fell', 'VBD'),
#  ('back', 'RB'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('antiquated', 'JJ'),
#  ('and', 'CC'),
#  ('rotten', 'JJ'),
#  ('constitution', 'NN'),
#  ('of', 'IN'),
#  ('_dogmatism_', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('again', 'RB'),
#  ('became', 'VBD'),
#  ('obnoxious', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('contempt', 'NN'),
#  ('from', 'IN'),
#  ('which', 'WDT'),
#  ('efforts', 'NNS'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('made', 'VBN'),
#  ('to', 'TO'),
#  ('save', 'VB'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('At', 'IN'),
#  ('present', 'JJ'),
#  (',', ','),
#  ('as', 'IN'),
#  ('all', 'DT'),
#  ('methods', 'NNS'),
#  (',', ','),
#  ('according', 'VBG'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('general', 'JJ'),
#  ('persuasion', 'NN'),
#  (',', ','),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('tried', 'VBN'),
#  ('in', 'IN'),
#  ('vain', 'NN'),
#  (',', ','),
#  ('there', 'EX'),
#  ('reigns', 'JJ'),
#  ('nought', 'NN'),
#  ('but', 'CC'),
#  ('weariness', 'NN'),
#  ('and', 'CC'),
#  ('complete', 'JJ'),
#  ('_indifferentism_—the', 'NNP'),
#  ('mother', 'NN'),
#  ('of', 'IN'),
#  ('chaos', 'NN'),
#  ('and', 'CC'),
#  ('night', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('scientific', 'JJ'),
#  ('world', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('time', 'NN'),
#  ('the', 'DT'),
#  ('source', 'NN'),
#  ('of', 'IN'),
#  (',', ','),
#  ('or', 'CC'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('the', 'DT'),
#  ('prelude', 'NN'),
#  ('to', 'TO'),
#  (',', ','),
#  ('the', 'DT'),
#  ('re-creation', 'NN'),
#  ('and', 'CC'),
#  ('reinstallation', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('science', 'NN'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('fallen', 'VBN'),
#  ('into', 'IN'),
#  ('confusion', 'NN'),
#  (',', ','),
#  ('obscurity', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('disuse', 'NN'),
#  ('from', 'IN'),
#  ('ill', 'NN'),
#  ('directed', 'VBN'),
#  ('effort', 'NN'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('in', 'IN'),
#  ('reality', 'NN'),
#  ('vain', 'NN'),
#  ('to', 'TO'),
#  ('profess', 'VB'),
#  ('_indifference_', 'NNP'),
#  ('in', 'IN'),
#  ('regard', 'NN'),
#  ('to', 'TO'),
#  ('such', 'JJ'),
#  ('inquiries', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('object', 'NN'),
#  ('of', 'IN'),
#  ('which', 'WDT'),
#  ('can', 'MD'),
#  ('not', 'RB'),
#  ('be', 'VB'),
#  ('indifferent', 'JJ'),
#  ('to', 'TO'),
#  ('humanity', 'NN'),
#  ('.', '.'),
#  ('Besides', 'IN'),
#  (',', ','),
#  ('these', 'DT'),
#  ('pretended', 'VBN'),
#  ('_indifferentists_', 'NN'),
#  (',', ','),
#  ('however', 'RB'),
#  ('much', 'JJ'),
#  ('they', 'PRP'),
#  ('may', 'MD'),
#  ('try', 'VB'),
#  ('to', 'TO'),
#  ('disguise', 'VB'),
#  ('themselves', 'PRP'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('assumption', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('popular', 'JJ'),
#  ('style', 'NN'),
#  ('and', 'CC'),
#  ('by', 'IN'),
#  ('changes', 'NNS'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('language', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('schools', 'NNS'),
#  (',', ','),
#  ('unavoidably', 'RB'),
#  ('fall', 'VB'),
#  ('into', 'IN'),
#  ('metaphysical', 'JJ'),
#  ('declarations', 'NNS'),
#  ('and', 'CC'),
#  ('propositions', 'NNS'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('they', 'PRP'),
#  ('profess', 'VBP'),
#  ('to', 'TO'),
#  ('regard', 'VB'),
#  ('with', 'IN'),
#  ('so', 'RB'),
#  ('much', 'JJ'),
#  ('contempt', 'NN'),
#  ('.', '.'),
#  ('At', 'IN'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('time', 'NN'),
#  (',', ','),
#  ('this', 'DT'),
#  ('indifference', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('has', 'VBZ'),
#  ('arisen', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('of', 'IN'),
#  ('science', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('which', 'WDT'),
#  ('relates', 'VBZ'),
#  ('to', 'TO'),
#  ('that', 'DT'),
#  ('kind', 'NN'),
#  ('of', 'IN'),
#  ('knowledge', 'NN'),
#  ('which', 'WDT'),
#  ('we', 'PRP'),
#  ('should', 'MD'),
#  ('wish', 'VB'),
#  ('to', 'TO'),
#  ('see', 'VB'),
#  ('destroyed', 'VBN'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('phenomenon', 'NN'),
#  ('that', 'WDT'),
#  ('well', 'RB'),
#  ('deserves', 'VBZ'),
#  ('our', 'PRP$'),
#  ('attention', 'NN'),
#  ('and', 'CC'),
#  ('reflection', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('plainly', 'RB'),
#  ('not', 'RB'),
#  ('the', 'DT'),
#  ('effect', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('levity', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('matured', 'JJ'),
#  ('_judgement_', 'NNP'),
#  ('[', 'NNP'),
#  ('1', 'CD'),
#  (']', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('age', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('refuses', 'VBZ'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('any', 'DT'),
#  ('longer', 'RBR'),
#  ('entertained', 'VBN'),
#  ('with', 'IN'),
#  ('illusory', 'NN'),
#  ('knowledge', 'NN'),
#  (',', ','),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  (',', ','),
#  ('in', 'IN'),
#  ('fact', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('call', 'NN'),
#  ('to', 'TO'),
#  ('reason', 'NN'),
#  (',', ','),
#  ('again', 'RB'),
#  ('to', 'TO'),
#  ('undertake', 'VB'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('laborious', 'JJ'),
#  ('of', 'IN'),
#  ('all', 'DT'),
#  ('tasks—that', 'DT'),
#  ('of', 'IN'),
#  ('self-examination', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('to', 'TO'),
#  ('establish', 'VB'),
#  ('a', 'DT'),
#  ('tribunal', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('may', 'MD'),
#  ('secure', 'VB'),
#  ('it', 'PRP'),
#  ('in', 'IN'),
#  ('its', 'PRP$'),
#  ('well-grounded', 'JJ'),
#  ('claims', 'NNS'),
#  (',', ','),
#  ('while', 'IN'),
#  ('it', 'PRP'),
#  ('pronounces', 'VBZ'),
#  ('against', 'IN'),
#  ('all', 'DT'),
#  ('baseless', 'JJ'),
#  ('assumptions', 'NNS'),
#  ('and', 'CC'),
#  ('pretensions', 'NNS'),
#  (',', ','),
#  ('not', 'RB'),
#  ('in', 'IN'),
#  ('an', 'DT'),
#  ('arbitrary', 'JJ'),
#  ('manner', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('according', 'VBG'),
#  ('to', 'TO'),
#  ('its', 'PRP$'),
#  ('own', 'JJ'),
#  ('eternal', 'JJ'),
#  ('and', 'CC'),
#  ('unchangeable', 'JJ'),
#  ('laws', 'NNS'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('tribunal', 'JJ'),
#  ('is', 'VBZ'),
#  ('nothing', 'NN'),
#  ('less', 'JJR'),
#  ('than', 'IN'),
#  ('the', 'DT'),
#  ('_Critical', 'JJ'),
#  ('Investigation', 'NNP'),
#  ('of', 'IN'),
#  ('Pure', 'NNP'),
#  ('Reason_', 'NNP'),
#  ('.', '.')]

# %%
#pattern = 'NP: {<DT>?<JJ>*<NN>}'
pattern = r"""
    NP: {<DT>?<JJ>*<NN>}    # Noun Phrase
    VP: {<VB.*>+<NP>?}      # Verb Phrase
    """

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   At/IN
#   first/JJ
#   ,/,
#   her/PRP$
#   (NP government/NN)
#   ,/,
#   under/IN
#   (NP the/DT administration/NN)
#   of/IN
#   the/DT
#   _dogmatists_/NNP
#   ,/,
#   (VP was/VBD (NP an/DT absolute/JJ _despotism_/NN))
#   ./.
#   But/CC
#   ,/,
#   as/IN
#   (NP the/DT legislative/JJ continued/NN)
#   to/TO
#   (VP show/VB)
#   traces/NNS
#   of/IN
#   (NP the/DT ancient/NN)
#   (NP barbaric/NN)
#   (NP rule/NN)
#   ,/,
#   her/PRP$
#   (NP empire/NN)
#   gradually/RB
#   (VP broke/VBD)
#   up/RP
#   ,/,
#   and/CC
#   (NP intestine/NN)
#   wars/NNS
#   (VP introduced/VBD (NP the/DT reign/NN))
#   of/IN
#   (NP _anarchy/NN)
#   ;/:
#   _/CC
#   while/IN
#   the/DT
#   _sceptics_/NNP
#   ,/,
#   like/IN
#   nomadic/JJ
#   tribes/NNS
#   ,/,
#   who/WP
#   (VP hate/VBP (NP a/DT permanent/JJ habitation/NN))
#   and/CC
#   (VP settled/VBD (NP mode/NN))
#   of/IN
#   (NP living/NN)
#   ,/,
#   (VP attacked/VBN)
#   from/IN
#   (NP time/NN)
#   to/TO
#   (NP time/NN)
#   those/DT
#   who/WP
#   (VP had/VBD organized/VBN)
#   themselves/PRP
#   into/IN
#   civil/JJ
#   communities/NNS
#   ./.
#   But/CC
#   their/PRP$
#   (NP number/NN)
#   (VP was/VBD)
#   ,/,
#   very/RB
#   happily/RB
#   ,/,
#   small/JJ
#   ;/:
#   and/CC
#   thus/RB
#   they/PRP
#   could/MD
#   not/RB
#   entirely/RB
#   (VP put/VB (NP a/DT stop/NN))
#   to/TO
#   the/DT
#   exertions/NNS
#   of/IN
#   those/DT
#   who/WP
#   (VP persisted/VBD)
#   in/IN
#   (VP raising/VBG)
#   new/JJ
#   edifices/NNS
#   ,/,
#   although/IN
#   on/IN
#   no/DT
#   (VP settled/VBN)
#   or/CC
#   (NP uniform/JJ plan/NN)
#   ./.
#   In/IN
#   recent/JJ
#   times/NNS
#   (NP the/DT hope/NN)
#   (VP dawned/VBD)
#   upon/IN
#   us/PRP
#   of/IN
#   (VP seeing/VBG)
#   those/DT
#   disputes/NNS
#   (VP settled/VBD)
#   ,/,
#   and/CC
#   (NP the/DT legitimacy/NN)
#   of/IN
#   her/PRP$
#   claims/NNS
#   (VP established/VBN)
#   by/IN
#   (NP a/DT kind/NN)
#   of/IN
#   (NP _physiology_/NN)
#   of/IN
#   (NP the/DT human/JJ understanding—that/NN)
#   of/IN
#   the/DT
#   celebrated/JJ
#   Locke/NNP
#   ./.
#   But/CC
#   it/PRP
#   (VP was/VBD found/VBN)
#   that—although/IN
#   it/PRP
#   (VP was/VBD affirmed/VBN)
#   that/IN
#   (NP this/DT so-called/JJ queen/NN)
#   could/MD
#   not/RB
#   (VP refer/VB)
#   her/PRP$
#   (NP descent/NN)
#   to/TO
#   any/DT
#   higher/JJR
#   (NP source/NN)
#   than/IN
#   that/DT
#   of/IN
#   (NP common/JJ experience/NN)
#   ,/,
#   (NP a/DT circumstance/NN)
#   which/WDT
#   necessarily/RB
#   (VP brought/VBD (NP suspicion/NN))
#   on/IN
#   her/PRP$
#   (NP claims—as/NN)
#   (NP this/DT _genealogy_/NN)
#   (VP was/VBD)
#   incorrect/JJ
#   ,/,
#   she/PRP
#   (VP persisted/VBD)
#   in/IN
#   (NP the/DT advancement/NN)
#   of/IN
#   her/PRP$
#   claims/NNS
#   to/TO
#   (VP sovereignty/VB)
#   ./.
#   Thus/NNP
#   metaphysics/NNS
#   necessarily/RB
#   (VP fell/VBD)
#   back/RB
#   into/IN
#   the/DT
#   antiquated/JJ
#   and/CC
#   (NP rotten/JJ constitution/NN)
#   of/IN
#   _dogmatism_/NNP
#   ,/,
#   and/CC
#   again/RB
#   (VP became/VBD)
#   obnoxious/JJ
#   to/TO
#   (NP the/DT contempt/NN)
#   from/IN
#   which/WDT
#   efforts/NNS
#   (VP had/VBD been/VBN made/VBN)
#   to/TO
#   (VP save/VB)
#   it/PRP
#   ./.
#   At/IN
#   present/JJ
#   ,/,
#   as/IN
#   all/DT
#   methods/NNS
#   ,/,
#   (VP according/VBG)
#   to/TO
#   (NP the/DT general/JJ persuasion/NN)
#   ,/,
#   (VP have/VBP been/VBN tried/VBN)
#   in/IN
#   (NP vain/NN)
#   ,/,
#   there/EX
#   (NP reigns/JJ nought/NN)
#   but/CC
#   (NP weariness/NN)
#   and/CC
#   complete/JJ
#   _indifferentism_—the/NNP
#   (NP mother/NN)
#   of/IN
#   (NP chaos/NN)
#   and/CC
#   (NP night/NN)
#   in/IN
#   (NP the/DT scientific/JJ world/NN)
#   ,/,
#   but/CC
#   at/IN
#   (NP the/DT same/JJ time/NN)
#   (NP the/DT source/NN)
#   of/IN
#   ,/,
#   or/CC
#   at/IN
#   least/JJS
#   (NP the/DT prelude/NN)
#   to/TO
#   ,/,
#   (NP the/DT re-creation/NN)
#   and/CC
#   (NP reinstallation/NN)
#   of/IN
#   (NP a/DT science/NN)
#   ,/,
#   when/WRB
#   it/PRP
#   (VP has/VBZ fallen/VBN)
#   into/IN
#   (NP confusion/NN)
#   ,/,
#   (NP obscurity/NN)
#   ,/,
#   and/CC
#   (NP disuse/NN)
#   from/IN
#   (NP ill/NN)
#   (VP directed/VBN (NP effort/NN))
#   ./.
#   For/IN
#   it/PRP
#   (VP is/VBZ)
#   in/IN
#   (NP reality/NN)
#   (NP vain/NN)
#   to/TO
#   (VP profess/VB)
#   _indifference_/NNP
#   in/IN
#   (NP regard/NN)
#   to/TO
#   such/JJ
#   inquiries/NNS
#   ,/,
#   (NP the/DT object/NN)
#   of/IN
#   which/WDT
#   can/MD
#   not/RB
#   (VP be/VB)
#   indifferent/JJ
#   to/TO
#   (NP humanity/NN)
#   ./.
#   Besides/IN
#   ,/,
#   these/DT
#   (VP pretended/VBN (NP _indifferentists_/NN))
#   ,/,
#   however/RB
#   much/JJ
#   they/PRP
#   may/MD
#   (VP try/VB)
#   to/TO
#   (VP disguise/VB)
#   themselves/PRP
#   by/IN
#   (NP the/DT assumption/NN)
#   of/IN
#   (NP a/DT popular/JJ style/NN)
#   and/CC
#   by/IN
#   changes/NNS
#   on/IN
#   (NP the/DT language/NN)
#   of/IN
#   the/DT
#   schools/NNS
#   ,/,
#   unavoidably/RB
#   (VP fall/VB)
#   into/IN
#   metaphysical/JJ
#   declarations/NNS
#   and/CC
#   propositions/NNS
#   ,/,
#   which/WDT
#   they/PRP
#   (VP profess/VBP)
#   to/TO
#   (VP regard/VB)
#   with/IN
#   so/RB
#   (NP much/JJ contempt/NN)
#   ./.
#   At/IN
#   (NP the/DT same/JJ time/NN)
#   ,/,
#   (NP this/DT indifference/NN)
#   ,/,
#   which/WDT
#   (VP has/VBZ arisen/VBN)
#   in/IN
#   (NP the/DT world/NN)
#   of/IN
#   (NP science/NN)
#   ,/,
#   and/CC
#   which/WDT
#   (VP relates/VBZ)
#   to/TO
#   (NP that/DT kind/NN)
#   of/IN
#   (NP knowledge/NN)
#   which/WDT
#   we/PRP
#   should/MD
#   (VP wish/VB)
#   to/TO
#   (VP see/VB destroyed/VBN)
#   the/DT
#   last/JJ
#   ,/,
#   (VP is/VBZ (NP a/DT phenomenon/NN))
#   that/WDT
#   well/RB
#   (VP deserves/VBZ)
#   our/PRP$
#   (NP attention/NN)
#   and/CC
#   (NP reflection/NN)
#   ./.
#   It/PRP
#   (VP is/VBZ)
#   plainly/RB
#   not/RB
#   (NP the/DT effect/NN)
#   of/IN
#   (NP the/DT levity/NN)
#   ,/,
#   but/CC
#   of/IN
#   the/DT
#   matured/JJ
#   _judgement_/NNP
#   [/NNP
#   1/CD
#   (NP ]/NN)
#   of/IN
#   (NP the/DT age/NN)
#   ,/,
#   which/WDT
#   (VP refuses/VBZ)
#   to/TO
#   (VP be/VB)
#   any/DT
#   longer/RBR
#   (VP entertained/VBN)
#   with/IN
#   (NP illusory/NN)
#   (NP knowledge/NN)
#   ,/,
#   It/PRP
#   (VP is/VBZ)
#   ,/,
#   in/IN
#   (NP fact/NN)
#   ,/,
#   (NP a/DT call/NN)
#   to/TO
#   (NP reason/NN)
#   ,/,
#   again/RB
#   to/TO
#   (VP undertake/VB)
#   the/DT
#   most/RBS
#   laborious/JJ
#   of/IN
#   all/DT
#   tasks—that/DT
#   of/IN
#   (NP self-examination/NN)
#   ,/,
#   and/CC
#   to/TO
#   (VP establish/VB (NP a/DT tribunal/NN))
#   ,/,
#   which/WDT
#   may/MD
#   (VP secure/VB)
#   it/PRP
#   in/IN
#   its/PRP$
#   well-grounded/JJ
#   claims/NNS
#   ,/,
#   while/IN
#   it/PRP
#   (VP pronounces/VBZ)
#   against/IN
#   all/DT
#   baseless/JJ
#   assumptions/NNS
#   and/CC
#   pretensions/NNS
#   ,/,
#   not/RB
#   in/IN
#   (NP an/DT arbitrary/JJ manner/NN)
#   ,/,
#   but/CC
#   (VP according/VBG)
#   to/TO
#   its/PRP$
#   own/JJ
#   eternal/JJ
#   and/CC
#   unchangeable/JJ
#   laws/NNS
#   ./.
#   This/DT
#   tribunal/JJ
#   (VP is/VBZ (NP nothing/NN))
#   less/JJR
#   than/IN
#   the/DT
#   _Critical/JJ
#   Investigation/NNP
#   of/IN
#   Pure/NNP
#   Reason_/NNP
#   ./.)

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('At', 'IN', 'O'),
#  ('first', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('her', 'PRP$', 'O'),
#  ('government', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('under', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('administration', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('_dogmatists_', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('was', 'VBD', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('absolute', 'JJ', 'I-NP'),
#  ('_despotism_', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('But', 'CC', 'O'),
#  (',', ',', 'O'),
#  ('as', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('legislative', 'JJ', 'I-NP'),
#  ('continued', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('show', 'VB', 'O'),
#  ('traces', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ancient', 'NN', 'I-NP'),
#  ('barbaric', 'NN', 'B-NP'),
#  ('rule', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('her', 'PRP$', 'O'),
#  ('empire', 'NN', 'B-NP'),
#  ('gradually', 'RB', 'O'),
#  ('broke', 'VBD', 'O'),
#  ('up', 'RP', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('intestine', 'NN', 'B-NP'),
#  ('wars', 'NNS', 'O'),
#  ('introduced', 'VBD', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('reign', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('_anarchy', 'NN', 'B-NP'),
#  (';', ':', 'O'),
#  ('_', 'CC', 'O'),
#  ('while', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('_sceptics_', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('like', 'IN', 'O'),
#  ('nomadic', 'JJ', 'O'),
#  ('tribes', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('who', 'WP', 'O'),
#  ('hate', 'VBP', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('permanent', 'JJ', 'I-NP'),
#  ('habitation', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('settled', 'VBD', 'O'),
#  ('mode', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('living', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('attacked', 'VBN', 'O'),
#  ('from', 'IN', 'O'),
#  ('time', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('time', 'NN', 'B-NP'),
#  ('those', 'DT', 'O'),
#  ('who', 'WP', 'O'),
#  ('had', 'VBD', 'O'),
#  ('organized', 'VBN', 'O'),
#  ('themselves', 'PRP', 'O'),
#  ('into', 'IN', 'O'),
#  ('civil', 'JJ', 'O'),
#  ('communities', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('But', 'CC', 'O'),
#  ('their', 'PRP$', 'O'),
#  ('number', 'NN', 'B-NP'),
#  ('was', 'VBD', 'O'),
#  (',', ',', 'O'),
#  ('very', 'RB', 'O'),
#  ('happily', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('small', 'JJ', 'O'),
#  (';', ':', 'O'),
#  ('and', 'CC', 'O'),
#  ('thus', 'RB', 'O'),
#  ('they', 'PRP', 'O'),
#  ('could', 'MD', 'O'),
#  ('not', 'RB', 'O'),
#  ('entirely', 'RB', 'O'),
#  ('put', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('stop', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'O'),
#  ('exertions', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('those', 'DT', 'O'),
#  ('who', 'WP', 'O'),
#  ('persisted', 'VBD', 'O'),
#  ('in', 'IN', 'O'),
#  ('raising', 'VBG', 'O'),
#  ('new', 'JJ', 'O'),
#  ('edifices', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('although', 'IN', 'O'),
#  ('on', 'IN', 'O'),
#  ('no', 'DT', 'O'),
#  ('settled', 'VBN', 'O'),
#  ('or', 'CC', 'O'),
#  ('uniform', 'JJ', 'B-NP'),
#  ('plan', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('recent', 'JJ', 'O'),
#  ('times', 'NNS', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('hope', 'NN', 'I-NP'),
#  ('dawned', 'VBD', 'O'),
#  ('upon', 'IN', 'O'),
#  ('us', 'PRP', 'O'),
#  ('of', 'IN', 'O'),
#  ('seeing', 'VBG', 'O'),
#  ('those', 'DT', 'O'),
#  ('disputes', 'NNS', 'O'),
#  ('settled', 'VBD', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('legitimacy', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('her', 'PRP$', 'O'),
#  ('claims', 'NNS', 'O'),
#  ('established', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('kind', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('_physiology_', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('human', 'JJ', 'I-NP'),
#  ('understanding—that', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('celebrated', 'JJ', 'O'),
#  ('Locke', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('But', 'CC', 'O'),
#  ('it', 'PRP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('found', 'VBN', 'O'),
#  ('that—although', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('affirmed', 'VBN', 'O'),
#  ('that', 'IN', 'O'),
#  ('this', 'DT', 'B-NP'),
#  ('so-called', 'JJ', 'I-NP'),
#  ('queen', 'NN', 'I-NP'),
#  ('could', 'MD', 'O'),
#  ('not', 'RB', 'O'),
#  ('refer', 'VB', 'O'),
#  ('her', 'PRP$', 'O'),
#  ('descent', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('any', 'DT', 'O'),
#  ('higher', 'JJR', 'O'),
#  ('source', 'NN', 'B-NP'),
#  ('than', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('of', 'IN', 'O'),
#  ('common', 'JJ', 'B-NP'),
#  ('experience', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('circumstance', 'NN', 'I-NP'),
#  ('which', 'WDT', 'O'),
#  ('necessarily', 'RB', 'O'),
#  ('brought', 'VBD', 'O'),
#  ('suspicion', 'NN', 'B-NP'),
#  ('on', 'IN', 'O'),
#  ('her', 'PRP$', 'O'),
#  ('claims—as', 'NN', 'B-NP'),
#  ('this', 'DT', 'B-NP'),
#  ('_genealogy_', 'NN', 'I-NP'),
#  ('was', 'VBD', 'O'),
#  ('incorrect', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('she', 'PRP', 'O'),
#  ('persisted', 'VBD', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('advancement', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('her', 'PRP$', 'O'),
#  ('claims', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('sovereignty', 'VB', 'O'),
#  ('.', '.', 'O'),
#  ('Thus', 'NNP', 'O'),
#  ('metaphysics', 'NNS', 'O'),
#  ('necessarily', 'RB', 'O'),
#  ('fell', 'VBD', 'O'),
#  ('back', 'RB', 'O'),
#  ('into', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('antiquated', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('rotten', 'JJ', 'B-NP'),
#  ('constitution', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('_dogmatism_', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('again', 'RB', 'O'),
#  ('became', 'VBD', 'O'),
#  ('obnoxious', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('contempt', 'NN', 'I-NP'),
#  ('from', 'IN', 'O'),
#  ('which', 'WDT', 'O'),
#  ('efforts', 'NNS', 'O'),
#  ('had', 'VBD', 'O'),
#  ('been', 'VBN', 'O'),
#  ('made', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('save', 'VB', 'O'),
#  ('it', 'PRP', 'O'),
#  ('.', '.', 'O'),
#  ('At', 'IN', 'O'),
#  ('present', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('as', 'IN', 'O'),
#  ('all', 'DT', 'O'),
#  ('methods', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('according', 'VBG', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('general', 'JJ', 'I-NP'),
#  ('persuasion', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('have', 'VBP', 'O'),
#  ('been', 'VBN', 'O'),
#  ('tried', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('vain', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('there', 'EX', 'O'),
#  ('reigns', 'JJ', 'B-NP'),
#  ('nought', 'NN', 'I-NP'),
#  ('but', 'CC', 'O'),
#  ('weariness', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('complete', 'JJ', 'O'),
#  ('_indifferentism_—the', 'NNP', 'O'),
#  ('mother', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('chaos', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('night', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('scientific', 'JJ', 'I-NP'),
#  ('world', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('same', 'JJ', 'I-NP'),
#  ('time', 'NN', 'I-NP'),
#  ('the', 'DT', 'B-NP'),
#  ('source', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  (',', ',', 'O'),
#  ('or', 'CC', 'O'),
#  ('at', 'IN', 'O'),
#  ('least', 'JJS', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('prelude', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('re-creation', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('reinstallation', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('science', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('when', 'WRB', 'O'),
#  ('it', 'PRP', 'O'),
#  ('has', 'VBZ', 'O'),
#  ('fallen', 'VBN', 'O'),
#  ('into', 'IN', 'O'),
#  ('confusion', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('obscurity', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('disuse', 'NN', 'B-NP'),
#  ('from', 'IN', 'O'),
#  ('ill', 'NN', 'B-NP'),
#  ('directed', 'VBN', 'O'),
#  ('effort', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('For', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('in', 'IN', 'O'),
#  ('reality', 'NN', 'B-NP'),
#  ('vain', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('profess', 'VB', 'O'),
#  ('_indifference_', 'NNP', 'O'),
#  ('in', 'IN', 'O'),
#  ('regard', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('such', 'JJ', 'O'),
#  ('inquiries', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('object', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('which', 'WDT', 'O'),
#  ('can', 'MD', 'O'),
#  ('not', 'RB', 'O'),
#  ('be', 'VB', 'O'),
#  ('indifferent', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('humanity', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Besides', 'IN', 'O'),
#  (',', ',', 'O'),
#  ('these', 'DT', 'O'),
#  ('pretended', 'VBN', 'O'),
#  ('_indifferentists_', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('however', 'RB', 'O'),
#  ('much', 'JJ', 'O'),
#  ('they', 'PRP', 'O'),
#  ('may', 'MD', 'O'),
#  ('try', 'VB', 'O'),
#  ('to', 'TO', 'O'),
#  ('disguise', 'VB', 'O'),
#  ('themselves', 'PRP', 'O'),
#  ('by', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('assumption', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('popular', 'JJ', 'I-NP'),
#  ('style', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('by', 'IN', 'O'),
#  ('changes', 'NNS', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('language', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('schools', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('unavoidably', 'RB', 'O'),
#  ('fall', 'VB', 'O'),
#  ('into', 'IN', 'O'),
#  ('metaphysical', 'JJ', 'O'),
#  ('declarations', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('propositions', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('they', 'PRP', 'O'),
#  ('profess', 'VBP', 'O'),
#  ('to', 'TO', 'O'),
#  ('regard', 'VB', 'O'),
#  ('with', 'IN', 'O'),
#  ('so', 'RB', 'O'),
#  ('much', 'JJ', 'B-NP'),
#  ('contempt', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('At', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('same', 'JJ', 'I-NP'),
#  ('time', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('this', 'DT', 'B-NP'),
#  ('indifference', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('has', 'VBZ', 'O'),
#  ('arisen', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('world', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('science', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('which', 'WDT', 'O'),
#  ('relates', 'VBZ', 'O'),
#  ('to', 'TO', 'O'),
#  ('that', 'DT', 'B-NP'),
#  ('kind', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('knowledge', 'NN', 'B-NP'),
#  ('which', 'WDT', 'O'),
#  ('we', 'PRP', 'O'),
#  ('should', 'MD', 'O'),
#  ('wish', 'VB', 'O'),
#  ('to', 'TO', 'O'),
#  ('see', 'VB', 'O'),
#  ('destroyed', 'VBN', 'O'),
#  ('the', 'DT', 'O'),
#  ('last', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('phenomenon', 'NN', 'I-NP'),
#  ('that', 'WDT', 'O'),
#  ('well', 'RB', 'O'),
#  ('deserves', 'VBZ', 'O'),
#  ('our', 'PRP$', 'O'),
#  ('attention', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('reflection', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('It', 'PRP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('plainly', 'RB', 'O'),
#  ('not', 'RB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('effect', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('levity', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('matured', 'JJ', 'O'),
#  ('_judgement_', 'NNP', 'O'),
#  ('[', 'NNP', 'O'),
#  ('1', 'CD', 'O'),
#  (']', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('age', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('refuses', 'VBZ', 'O'),
#  ('to', 'TO', 'O'),
#  ('be', 'VB', 'O'),
#  ('any', 'DT', 'O'),
#  ('longer', 'RBR', 'O'),
#  ('entertained', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('illusory', 'NN', 'B-NP'),
#  ('knowledge', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('It', 'PRP', 'O'),
#  ('is', 'VBZ', 'O'),
#  (',', ',', 'O'),
#  ('in', 'IN', 'O'),
#  ('fact', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('call', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('reason', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('again', 'RB', 'O'),
#  ('to', 'TO', 'O'),
#  ('undertake', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('most', 'RBS', 'O'),
#  ('laborious', 'JJ', 'O'),
#  ('of', 'IN', 'O'),
#  ('all', 'DT', 'O'),
#  ('tasks—that', 'DT', 'O'),
#  ('of', 'IN', 'O'),
#  ('self-examination', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('to', 'TO', 'O'),
#  ('establish', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('tribunal', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('may', 'MD', 'O'),
#  ('secure', 'VB', 'O'),
#  ('it', 'PRP', 'O'),
#  ('in', 'IN', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('well-grounded', 'JJ', 'O'),
#  ('claims', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('while', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('pronounces', 'VBZ', 'O'),
#  ('against', 'IN', 'O'),
#  ('all', 'DT', 'O'),
#  ('baseless', 'JJ', 'O'),
#  ('assumptions', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('pretensions', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('not', 'RB', 'O'),
#  ('in', 'IN', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('arbitrary', 'JJ', 'I-NP'),
#  ('manner', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('according', 'VBG', 'O'),
#  ('to', 'TO', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('own', 'JJ', 'O'),
#  ('eternal', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('unchangeable', 'JJ', 'O'),
#  ('laws', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('This', 'DT', 'O'),
#  ('tribunal', 'JJ', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('nothing', 'NN', 'B-NP'),
#  ('less', 'JJR', 'O'),
#  ('than', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('_Critical', 'JJ', 'O'),
#  ('Investigation', 'NNP', 'O'),
#  ('of', 'IN', 'O'),
#  ('Pure', 'NNP', 'O'),
#  ('Reason_', 'NNP', 'O'),
#  ('.', '.', 'O')]

# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/dominikpichler/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/dominikpichler/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/dominikpichler/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/dominikpichler/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
from nltk import pos_tag, word_tokenize
from nltk.chunk import ne_chunk

ne_tree = ne_chunk(pos_tag(word_tokenize(text)))
print((ne_tree))
# Out:
# (S
#   At/IN
#   first/JJ
#   ,/,
#   her/PRP$
#   government/NN
#   ,/,
#   under/IN
#   the/DT
#   administration/NN
#   of/IN
#   the/DT
#   _dogmatists_/NNP
#   ,/,
#   was/VBD
#   an/DT
#   absolute/JJ
#   _despotism_/NN
#   ./.
#   But/CC
#   ,/,
#   as/IN
#   the/DT
#   legislative/JJ
#   continued/NN
#   to/TO
#   show/VB
#   traces/NNS
#   of/IN
#   the/DT
#   ancient/NN
#   barbaric/NN
#   rule/NN
#   ,/,
#   her/PRP$
#   empire/NN
#   gradually/RB
#   broke/VBD
#   up/RP
#   ,/,
#   and/CC
#   intestine/NN
#   wars/NNS
#   introduced/VBD
#   the/DT
#   reign/NN
#   of/IN
#   _anarchy/NN
#   ;/:
#   _/CC
#   while/IN
#   the/DT
#   _sceptics_/NNP
#   ,/,
#   like/IN
#   nomadic/JJ
#   tribes/NNS
#   ,/,
#   who/WP
#   hate/VBP
#   a/DT
#   permanent/JJ
#   habitation/NN
#   and/CC
#   settled/VBD
#   mode/NN
#   of/IN
#   living/NN
#   ,/,
#   attacked/VBN
#   from/IN
#   time/NN
#   to/TO
#   time/NN
#   those/DT
#   who/WP
#   had/VBD
#   organized/VBN
#   themselves/PRP
#   into/IN
#   civil/JJ
#   communities/NNS
#   ./.
#   But/CC
#   their/PRP$
#   number/NN
#   was/VBD
#   ,/,
#   very/RB
#   happily/RB
#   ,/,
#   small/JJ
#   ;/:
#   and/CC
#   thus/RB
#   they/PRP
#   could/MD
#   not/RB
#   entirely/RB
#   put/VB
#   a/DT
#   stop/NN
#   to/TO
#   the/DT
#   exertions/NNS
#   of/IN
#   those/DT
#   who/WP
#   persisted/VBD
#   in/IN
#   raising/VBG
#   new/JJ
#   edifices/NNS
#   ,/,
#   although/IN
#   on/IN
#   no/DT
#   settled/VBN
#   or/CC
#   uniform/JJ
#   plan/NN
#   ./.
#   In/IN
#   recent/JJ
#   times/NNS
#   the/DT
#   hope/NN
#   dawned/VBD
#   upon/IN
#   us/PRP
#   of/IN
#   seeing/VBG
#   those/DT
#   disputes/NNS
#   settled/VBD
#   ,/,
#   and/CC
#   the/DT
#   legitimacy/NN
#   of/IN
#   her/PRP$
#   claims/NNS
#   established/VBN
#   by/IN
#   a/DT
#   kind/NN
#   of/IN
#   _physiology_/NN
#   of/IN
#   the/DT
#   human/JJ
#   understanding—that/NN
#   of/IN
#   the/DT
#   celebrated/JJ
#   Locke/NNP
#   ./.
#   But/CC
#   it/PRP
#   was/VBD
#   found/VBN
#   that—although/IN
#   it/PRP
#   was/VBD
#   affirmed/VBN
#   that/IN
#   this/DT
#   so-called/JJ
#   queen/NN
#   could/MD
#   not/RB
#   refer/VB
#   her/PRP$
#   descent/NN
#   to/TO
#   any/DT
#   higher/JJR
#   source/NN
#   than/IN
#   that/DT
#   of/IN
#   common/JJ
#   experience/NN
#   ,/,
#   a/DT
#   circumstance/NN
#   which/WDT
#   necessarily/RB
#   brought/VBD
#   suspicion/NN
#   on/IN
#   her/PRP$
#   claims—as/NN
#   this/DT
#   _genealogy_/NN
#   was/VBD
#   incorrect/JJ
#   ,/,
#   she/PRP
#   persisted/VBD
#   in/IN
#   the/DT
#   advancement/NN
#   of/IN
#   her/PRP$
#   claims/NNS
#   to/TO
#   sovereignty/VB
#   ./.
#   Thus/NNP
#   metaphysics/NNS
#   necessarily/RB
#   fell/VBD
#   back/RB
#   into/IN
#   the/DT
#   antiquated/JJ
#   and/CC
#   rotten/JJ
#   constitution/NN
#   of/IN
#   _dogmatism_/NNP
#   ,/,
#   and/CC
#   again/RB
#   became/VBD
#   obnoxious/JJ
#   to/TO
#   the/DT
#   contempt/NN
#   from/IN
#   which/WDT
#   efforts/NNS
#   had/VBD
#   been/VBN
#   made/VBN
#   to/TO
#   save/VB
#   it/PRP
#   ./.
#   At/IN
#   present/JJ
#   ,/,
#   as/IN
#   all/DT
#   methods/NNS
#   ,/,
#   according/VBG
#   to/TO
#   the/DT
#   general/JJ
#   persuasion/NN
#   ,/,
#   have/VBP
#   been/VBN
#   tried/VBN
#   in/IN
#   vain/NN
#   ,/,
#   there/EX
#   reigns/JJ
#   nought/NN
#   but/CC
#   weariness/NN
#   and/CC
#   complete/JJ
#   _indifferentism_—the/NNP
#   mother/NN
#   of/IN
#   chaos/NN
#   and/CC
#   night/NN
#   in/IN
#   the/DT
#   scientific/JJ
#   world/NN
#   ,/,
#   but/CC
#   at/IN
#   the/DT
#   same/JJ
#   time/NN
#   the/DT
#   source/NN
#   of/IN
#   ,/,
#   or/CC
#   at/IN
#   least/JJS
#   the/DT
#   prelude/NN
#   to/TO
#   ,/,
#   the/DT
#   re-creation/NN
#   and/CC
#   reinstallation/NN
#   of/IN
#   a/DT
#   science/NN
#   ,/,
#   when/WRB
#   it/PRP
#   has/VBZ
#   fallen/VBN
#   into/IN
#   confusion/NN
#   ,/,
#   obscurity/NN
#   ,/,
#   and/CC
#   disuse/NN
#   from/IN
#   ill/NN
#   directed/VBN
#   effort/NN
#   ./.
#   For/IN
#   it/PRP
#   is/VBZ
#   in/IN
#   reality/NN
#   vain/NN
#   to/TO
#   profess/VB
#   _indifference_/NNP
#   in/IN
#   regard/NN
#   to/TO
#   such/JJ
#   inquiries/NNS
#   ,/,
#   the/DT
#   object/NN
#   of/IN
#   which/WDT
#   can/MD
#   not/RB
#   be/VB
#   indifferent/JJ
#   to/TO
#   humanity/NN
#   ./.
#   Besides/IN
#   ,/,
#   these/DT
#   pretended/VBN
#   _indifferentists_/NN
#   ,/,
#   however/RB
#   much/JJ
#   they/PRP
#   may/MD
#   try/VB
#   to/TO
#   disguise/VB
#   themselves/PRP
#   by/IN
#   the/DT
#   assumption/NN
#   of/IN
#   a/DT
#   popular/JJ
#   style/NN
#   and/CC
#   by/IN
#   changes/NNS
#   on/IN
#   the/DT
#   language/NN
#   of/IN
#   the/DT
#   schools/NNS
#   ,/,
#   unavoidably/RB
#   fall/VB
#   into/IN
#   metaphysical/JJ
#   declarations/NNS
#   and/CC
#   propositions/NNS
#   ,/,
#   which/WDT
#   they/PRP
#   profess/VBP
#   to/TO
#   regard/VB
#   with/IN
#   so/RB
#   much/JJ
#   contempt/NN
#   ./.
#   At/IN
#   the/DT
#   same/JJ
#   time/NN
#   ,/,
#   this/DT
#   indifference/NN
#   ,/,
#   which/WDT
#   has/VBZ
#   arisen/VBN
#   in/IN
#   the/DT
#   world/NN
#   of/IN
#   science/NN
#   ,/,
#   and/CC
#   which/WDT
#   relates/VBZ
#   to/TO
#   that/DT
#   kind/NN
#   of/IN
#   knowledge/NN
#   which/WDT
#   we/PRP
#   should/MD
#   wish/VB
#   to/TO
#   see/VB
#   destroyed/VBN
#   the/DT
#   last/JJ
#   ,/,
#   is/VBZ
#   a/DT
#   phenomenon/NN
#   that/WDT
#   well/RB
#   deserves/VBZ
#   our/PRP$
#   attention/NN
#   and/CC
#   reflection/NN
#   ./.
#   It/PRP
#   is/VBZ
#   plainly/RB
#   not/RB
#   the/DT
#   effect/NN
#   of/IN
#   the/DT
#   levity/NN
#   ,/,
#   but/CC
#   of/IN
#   the/DT
#   matured/JJ
#   _judgement_/NNP
#   [/NNP
#   1/CD
#   ]/NN
#   of/IN
#   the/DT
#   age/NN
#   ,/,
#   which/WDT
#   refuses/VBZ
#   to/TO
#   be/VB
#   any/DT
#   longer/RBR
#   entertained/VBN
#   with/IN
#   illusory/NN
#   knowledge/NN
#   ,/,
#   It/PRP
#   is/VBZ
#   ,/,
#   in/IN
#   fact/NN
#   ,/,
#   a/DT
#   call/NN
#   to/TO
#   reason/NN
#   ,/,
#   again/RB
#   to/TO
#   undertake/VB
#   the/DT
#   most/RBS
#   laborious/JJ
#   of/IN
#   all/DT
#   tasks—that/DT
#   of/IN
#   self-examination/NN
#   ,/,
#   and/CC
#   to/TO
#   establish/VB
#   a/DT
#   tribunal/NN
#   ,/,
#   which/WDT
#   may/MD
#   secure/VB
#   it/PRP
#   in/IN
#   its/PRP$
#   well-grounded/JJ
#   claims/NNS
#   ,/,
#   while/IN
#   it/PRP
#   pronounces/VBZ
#   against/IN
#   all/DT
#   baseless/JJ
#   assumptions/NNS
#   and/CC
#   pretensions/NNS
#   ,/,
#   not/RB
#   in/IN
#   an/DT
#   arbitrary/JJ
#   manner/NN
#   ,/,
#   but/CC
#   according/VBG
#   to/TO
#   its/PRP$
#   own/JJ
#   eternal/JJ
#   and/CC
#   unchangeable/JJ
#   laws/NNS
#   ./.
#   This/DT
#   tribunal/JJ
#   is/VBZ
#   nothing/NN
#   less/JJR
#   than/IN
#   the/DT
#   (ORGANIZATION _Critical/JJ Investigation/NNP)
#   of/IN
#   (ORGANIZATION Pure/NNP Reason_/NNP)
#   ./.)

# %%
import pandas as pd
type(iob_tagged)
df = pd.DataFrame.from_records(iob_tagged)
# Out:
# /var/folders/d2/jkwt52_n7kv66n_lj3trvtxw0000gn/T/ipykernel_65882/3744328505.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df
# Out:
#                  0     1     2
# 0               At    IN     O
# 1            first    JJ     O
# 2                ,     ,     O
# 3              her  PRP$     O
# 4       government    NN  B-NP
# ..             ...   ...   ...
# 542  Investigation   NNP     O
# 543             of    IN     O
# 544           Pure   NNP     O
# 545        Reason_   NNP     O
# 546              .     .     O
#
# [547 rows x 3 columns]
