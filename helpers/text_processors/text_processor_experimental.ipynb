# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
file_path =  '../resources/raw_input_data/The_critique_of_pure_reason.txt'


f = open(file_path,"r")
text = f.read()
print(text)
# Out:
# At first, her government, under the administration of the _dogmatists_,
# was an absolute _despotism_. But, as the legislative continued to show
# traces of the ancient barbaric rule, her empire gradually broke up, and
# intestine wars introduced the reign of _anarchy;_ while the _sceptics_,
# like nomadic tribes, who hate a permanent habitation and settled mode
# of living, attacked from time to time those who had organized
# themselves into civil communities. But their number was, very happily,
# small; and thus they could not entirely put a stop to the exertions of
# those who persisted in raising new edifices, although on no settled or
# uniform plan. In recent times the hope dawned upon us of seeing those
# disputes settled, and the legitimacy of her claims established by a
# kind of _physiology_ of the human understanding—that of the celebrated
# Locke. But it was found that—although it was affirmed that this
# so-called queen could not refer her descent to any higher source than
# that of common experience, a circumstance which necessarily brought
# suspicion on her claims—as this _genealogy_ was incorrect, she
# persisted in the advancement of her claims to sovereignty. Thus
# metaphysics necessarily fell back into the antiquated and rotten
# constitution of _dogmatism_, and again became obnoxious to the contempt
# from which efforts had been made to save it. At present, as all
# methods, according to the general persuasion, have been tried in vain,
# there reigns nought but weariness and complete _indifferentism_—the
# mother of chaos and night in the scientific world, but at the same time
# the source of, or at least the prelude to, the re-creation and
# reinstallation of a science, when it has fallen into confusion,
# obscurity, and disuse from ill directed effort.
#
# For it is in reality vain to profess _indifference_ in regard to such
# inquiries, the object of which cannot be indifferent to humanity.
# Besides, these pretended _indifferentists_, however much they may try
# to disguise themselves by the assumption of a popular style and by
# changes on the language of the schools, unavoidably fall into
# metaphysical declarations and propositions, which they profess to
# regard with so much contempt. At the same time, this indifference,
# which has arisen in the world of science, and which relates to that
# kind of knowledge which we should wish to see destroyed the last, is a
# phenomenon that well deserves our attention and reflection. It is
# plainly not the effect of the levity, but of the matured _judgement_[1]
# of the age, which refuses to be any longer entertained with illusory
# knowledge, It is, in fact, a call to reason, again to undertake the
# most laborious of all tasks—that of self-examination, and to establish
# a tribunal, which may secure it in its well-grounded claims, while it
# pronounces against all baseless assumptions and pretensions, not in an
# arbitrary manner, but according to its own eternal and unchangeable
# laws. This tribunal is nothing less than the _Critical Investigation of
# Pure Reason_.

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
# Just tokenise text and add POS Tags

sent = preprocess(text)
sent
# Out:
# list

# %%
my_string = ",".join(str(element) for element in sent)
my_string
# Out:
# "('At', 'IN'),('first', 'JJ'),(',', ','),('her', 'PRP$'),('government', 'NN'),(',', ','),('under', 'IN'),('the', 'DT'),('administration', 'NN'),('of', 'IN'),('the', 'DT'),('_dogmatists_', 'NNP'),(',', ','),('was', 'VBD'),('an', 'DT'),('absolute', 'JJ'),('_despotism_', 'NN'),('.', '.'),('But', 'CC'),(',', ','),('as', 'IN'),('the', 'DT'),('legislative', 'JJ'),('continued', 'NN'),('to', 'TO'),('show', 'VB'),('traces', 'NNS'),('of', 'IN'),('the', 'DT'),('ancient', 'NN'),('barbaric', 'NN'),('rule', 'NN'),(',', ','),('her', 'PRP$'),('empire', 'NN'),('gradually', 'RB'),('broke', 'VBD'),('up', 'RP'),(',', ','),('and', 'CC'),('intestine', 'NN'),('wars', 'NNS'),('introduced', 'VBD'),('the', 'DT'),('reign', 'NN'),('of', 'IN'),('_anarchy', 'NN'),(';', ':'),('_', 'CC'),('while', 'IN'),('the', 'DT'),('_sceptics_', 'NNP'),(',', ','),('like', 'IN'),('nomadic', 'JJ'),('tribes', 'NNS'),(',', ','),('who', 'WP'),('hate', 'VBP'),('a', 'DT'),('permanent', 'JJ'),('habitation', 'NN'),('and', 'CC'),('settled', 'VBD'),('mode', 'NN'),('of', 'IN'),('living', 'NN'),(',', ','),('attacked', 'VBN'),('from', 'IN'),('time', 'NN'),('to', 'TO'),('time', 'NN'),('those', 'DT'),('who', 'WP'),('had', 'VBD'),('organized', 'VBN'),('themselves', 'PRP'),('into', 'IN'),('civil', 'JJ'),('communities', 'NNS'),('.', '.'),('But', 'CC'),('their', 'PRP$'),('number', 'NN'),('was', 'VBD'),(',', ','),('very', 'RB'),('happily', 'RB'),(',', ','),('small', 'JJ'),(';', ':'),('and', 'CC'),('thus', 'RB'),('they', 'PRP'),('could', 'MD'),('not', 'RB'),('entirely', 'RB'),('put', 'VB'),('a', 'DT'),('stop', 'NN'),('to', 'TO'),('the', 'DT'),('exertions', 'NNS'),('of', 'IN'),('those', 'DT'),('who', 'WP'),('persisted', 'VBD'),('in', 'IN'),('raising', 'VBG'),('new', 'JJ'),('edifices', 'NNS'),(',', ','),('although', 'IN'),('on', 'IN'),('no', 'DT'),('settled', 'VBN'),('or', 'CC'),('uniform', 'JJ'),('plan', 'NN'),('.', '.'),('In', 'IN'),('recent', 'JJ'),('times', 'NNS'),('the', 'DT'),('hope', 'NN'),('dawned', 'VBD'),('upon', 'IN'),('us', 'PRP'),('of', 'IN'),('seeing', 'VBG'),('those', 'DT'),('disputes', 'NNS'),('settled', 'VBD'),(',', ','),('and', 'CC'),('the', 'DT'),('legitimacy', 'NN'),('of', 'IN'),('her', 'PRP$'),('claims', 'NNS'),('established', 'VBN'),('by', 'IN'),('a', 'DT'),('kind', 'NN'),('of', 'IN'),('_physiology_', 'NN'),('of', 'IN'),('the', 'DT'),('human', 'JJ'),('understanding—that', 'NN'),('of', 'IN'),('the', 'DT'),('celebrated', 'JJ'),('Locke', 'NNP'),('.', '.'),('But', 'CC'),('it', 'PRP'),('was', 'VBD'),('found', 'VBN'),('that—although', 'IN'),('it', 'PRP'),('was', 'VBD'),('affirmed', 'VBN'),('that', 'IN'),('this', 'DT'),('so-called', 'JJ'),('queen', 'NN'),('could', 'MD'),('not', 'RB'),('refer', 'VB'),('her', 'PRP$'),('descent', 'NN'),('to', 'TO'),('any', 'DT'),('higher', 'JJR'),('source', 'NN'),('than', 'IN'),('that', 'DT'),('of', 'IN'),('common', 'JJ'),('experience', 'NN'),(',', ','),('a', 'DT'),('circumstance', 'NN'),('which', 'WDT'),('necessarily', 'RB'),('brought', 'VBD'),('suspicion', 'NN'),('on', 'IN'),('her', 'PRP$'),('claims—as', 'NN'),('this', 'DT'),('_genealogy_', 'NN'),('was', 'VBD'),('incorrect', 'JJ'),(',', ','),('she', 'PRP'),('persisted', 'VBD'),('in', 'IN'),('the', 'DT'),('advancement', 'NN'),('of', 'IN'),('her', 'PRP$'),('claims', 'NNS'),('to', 'TO'),('sovereignty', 'VB'),('.', '.'),('Thus', 'NNP'),('metaphysics', 'NNS'),('necessarily', 'RB'),('fell', 'VBD'),('back', 'RB'),('into', 'IN'),('the', 'DT'),('antiquated', 'JJ'),('and', 'CC'),('rotten', 'JJ'),('constitution', 'NN'),('of', 'IN'),('_dogmatism_', 'NNP'),(',', ','),('and', 'CC'),('again', 'RB'),('became', 'VBD'),('obnoxious', 'JJ'),('to', 'TO'),('the', 'DT'),('contempt', 'NN'),('from', 'IN'),('which', 'WDT'),('efforts', 'NNS'),('had', 'VBD'),('been', 'VBN'),('made', 'VBN'),('to', 'TO'),('save', 'VB'),('it', 'PRP'),('.', '.'),('At', 'IN'),('present', 'JJ'),(',', ','),('as', 'IN'),('all', 'DT'),('methods', 'NNS'),(',', ','),('according', 'VBG'),('to', 'TO'),('the', 'DT'),('general', 'JJ'),('persuasion', 'NN'),( ...

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
# used to chunck parts of sentences :)

# %%
cp = nltk.RegexpParser(pattern)
tree_cs = cp.parse(sent)
print(tree_cs)
# Out:
# (S
#   At/IN
#   first/JJ
#   ,/,
#   her/PRP$
#   (NP government/NN)
#   ,/,
#   under/IN
#   (NP the/DT administration/NN)
#   of/IN
#   the/DT
#   _dogmatists_/NNP
#   ,/,
#   was/VBD
#   (NP an/DT absolute/JJ _despotism_/NN)
#   ./.
#   But/CC
#   ,/,
#   as/IN
#   (NP the/DT legislative/JJ continued/NN)
#   to/TO
#   show/VB
#   traces/NNS
#   of/IN
#   (NP the/DT ancient/NN)
#   (NP barbaric/NN)
#   (NP rule/NN)
#   ,/,
#   her/PRP$
#   (NP empire/NN)
#   gradually/RB
#   broke/VBD
#   up/RP
#   ,/,
#   and/CC
#   (NP intestine/NN)
#   wars/NNS
#   introduced/VBD
#   (NP the/DT reign/NN)
#   of/IN
#   (NP _anarchy/NN)
#   ;/:
#   _/CC
#   while/IN
#   the/DT
#   _sceptics_/NNP
#   ,/,
#   like/IN
#   nomadic/JJ
#   tribes/NNS
#   ,/,
#   who/WP
#   hate/VBP
#   (NP a/DT permanent/JJ habitation/NN)
#   and/CC
#   settled/VBD
#   (NP mode/NN)
#   of/IN
#   (NP living/NN)
#   ,/,
#   attacked/VBN
#   from/IN
#   (NP time/NN)
#   to/TO
#   (NP time/NN)
#   those/DT
#   who/WP
#   had/VBD
#   organized/VBN
#   themselves/PRP
#   into/IN
#   civil/JJ
#   communities/NNS
#   ./.
#   But/CC
#   their/PRP$
#   (NP number/NN)
#   was/VBD
#   ,/,
#   very/RB
#   happily/RB
#   ,/,
#   small/JJ
#   ;/:
#   and/CC
#   thus/RB
#   they/PRP
#   could/MD
#   not/RB
#   entirely/RB
#   put/VB
#   (NP a/DT stop/NN)
#   to/TO
#   the/DT
#   exertions/NNS
#   of/IN
#   those/DT
#   who/WP
#   persisted/VBD
#   in/IN
#   raising/VBG
#   new/JJ
#   edifices/NNS
#   ,/,
#   although/IN
#   on/IN
#   no/DT
#   settled/VBN
#   or/CC
#   (NP uniform/JJ plan/NN)
#   ./.
#   In/IN
#   recent/JJ
#   times/NNS
#   (NP the/DT hope/NN)
#   dawned/VBD
#   upon/IN
#   us/PRP
#   of/IN
#   seeing/VBG
#   those/DT
#   disputes/NNS
#   settled/VBD
#   ,/,
#   and/CC
#   (NP the/DT legitimacy/NN)
#   of/IN
#   her/PRP$
#   claims/NNS
#   established/VBN
#   by/IN
#   (NP a/DT kind/NN)
#   of/IN
#   (NP _physiology_/NN)
#   of/IN
#   (NP the/DT human/JJ understanding—that/NN)
#   of/IN
#   the/DT
#   celebrated/JJ
#   Locke/NNP
#   ./.
#   But/CC
#   it/PRP
#   was/VBD
#   found/VBN
#   that—although/IN
#   it/PRP
#   was/VBD
#   affirmed/VBN
#   that/IN
#   (NP this/DT so-called/JJ queen/NN)
#   could/MD
#   not/RB
#   refer/VB
#   her/PRP$
#   (NP descent/NN)
#   to/TO
#   any/DT
#   higher/JJR
#   (NP source/NN)
#   than/IN
#   that/DT
#   of/IN
#   (NP common/JJ experience/NN)
#   ,/,
#   (NP a/DT circumstance/NN)
#   which/WDT
#   necessarily/RB
#   brought/VBD
#   (NP suspicion/NN)
#   on/IN
#   her/PRP$
#   (NP claims—as/NN)
#   (NP this/DT _genealogy_/NN)
#   was/VBD
#   incorrect/JJ
#   ,/,
#   she/PRP
#   persisted/VBD
#   in/IN
#   (NP the/DT advancement/NN)
#   of/IN
#   her/PRP$
#   claims/NNS
#   to/TO
#   sovereignty/VB
#   ./.
#   Thus/NNP
#   metaphysics/NNS
#   necessarily/RB
#   fell/VBD
#   back/RB
#   into/IN
#   the/DT
#   antiquated/JJ
#   and/CC
#   (NP rotten/JJ constitution/NN)
#   of/IN
#   _dogmatism_/NNP
#   ,/,
#   and/CC
#   again/RB
#   became/VBD
#   obnoxious/JJ
#   to/TO
#   (NP the/DT contempt/NN)
#   from/IN
#   which/WDT
#   efforts/NNS
#   had/VBD
#   been/VBN
#   made/VBN
#   to/TO
#   save/VB
#   it/PRP
#   ./.
#   At/IN
#   present/JJ
#   ,/,
#   as/IN
#   all/DT
#   methods/NNS
#   ,/,
#   according/VBG
#   to/TO
#   (NP the/DT general/JJ persuasion/NN)
#   ,/,
#   have/VBP
#   been/VBN
#   tried/VBN
#   in/IN
#   (NP vain/NN)
#   ,/,
#   there/EX
#   (NP reigns/JJ nought/NN)
#   but/CC
#   (NP weariness/NN)
#   and/CC
#   complete/JJ
#   _indifferentism_—the/NNP
#   (NP mother/NN)
#   of/IN
#   (NP chaos/NN)
#   and/CC
#   (NP night/NN)
#   in/IN
#   (NP the/DT scientific/JJ world/NN)
#   ,/,
#   but/CC
#   at/IN
#   (NP the/DT same/JJ time/NN)
#   (NP the/DT source/NN)
#   of/IN
#   ,/,
#   or/CC
#   at/IN
#   least/JJS
#   (NP the/DT prelude/NN)
#   to/TO
#   ,/,
#   (NP the/DT re-creation/NN)
#   and/CC
#   (NP reinstallation/NN)
#   of/IN
#   (NP a/DT science/NN)
#   ,/,
#   when/WRB
#   it/PRP
#   has/VBZ
#   fallen/VBN
#   into/IN
#   (NP confusion/NN)
#   ,/,
#   (NP obscurity/NN)
#   ,/,
#   and/CC
#   (NP disuse/NN)
#   from/IN
#   (NP ill/NN)
#   directed/VBN
#   (NP effort/NN)
#   ./.
#   For/IN
#   it/PRP
#   is/VBZ
#   in/IN
#   (NP reality/NN)
#   (NP vain/NN)
#   to/TO
#   profess/VB
#   _indifference_/NNP
#   in/IN
#   (NP regard/NN)
#   to/TO
#   such/JJ
#   inquiries/NNS
#   ,/,
#   (NP the/DT object/NN)
#   of/IN
#   which/WDT
#   can/MD
#   not/RB
#   be/VB
#   indifferent/JJ
#   to/TO
#   (NP humanity/NN)
#   ./.
#   Besides/IN
#   ,/,
#   these/DT
#   pretended/VBN
#   (NP _indifferentists_/NN)
#   ,/,
#   however/RB
#   much/JJ
#   they/PRP
#   may/MD
#   try/VB
#   to/TO
#   disguise/VB
#   themselves/PRP
#   by/IN
#   (NP the/DT assumption/NN)
#   of/IN
#   (NP a/DT popular/JJ style/NN)
#   and/CC
#   by/IN
#   changes/NNS
#   on/IN
#   (NP the/DT language/NN)
#   of/IN
#   the/DT
#   schools/NNS
#   ,/,
#   unavoidably/RB
#   fall/VB
#   into/IN
#   metaphysical/JJ
#   declarations/NNS
#   and/CC
#   propositions/NNS
#   ,/,
#   which/WDT
#   they/PRP
#   profess/VBP
#   to/TO
#   regard/VB
#   with/IN
#   so/RB
#   (NP much/JJ contempt/NN)
#   ./.
#   At/IN
#   (NP the/DT same/JJ time/NN)
#   ,/,
#   (NP this/DT indifference/NN)
#   ,/,
#   which/WDT
#   has/VBZ
#   arisen/VBN
#   in/IN
#   (NP the/DT world/NN)
#   of/IN
#   (NP science/NN)
#   ,/,
#   and/CC
#   which/WDT
#   relates/VBZ
#   to/TO
#   (NP that/DT kind/NN)
#   of/IN
#   (NP knowledge/NN)
#   which/WDT
#   we/PRP
#   should/MD
#   wish/VB
#   to/TO
#   see/VB
#   destroyed/VBN
#   the/DT
#   last/JJ
#   ,/,
#   is/VBZ
#   (NP a/DT phenomenon/NN)
#   that/WDT
#   well/RB
#   deserves/VBZ
#   our/PRP$
#   (NP attention/NN)
#   and/CC
#   (NP reflection/NN)
#   ./.
#   It/PRP
#   is/VBZ
#   plainly/RB
#   not/RB
#   (NP the/DT effect/NN)
#   of/IN
#   (NP the/DT levity/NN)
#   ,/,
#   but/CC
#   of/IN
#   the/DT
#   matured/JJ
#   _judgement_/NNP
#   [/NNP
#   1/CD
#   (NP ]/NN)
#   of/IN
#   (NP the/DT age/NN)
#   ,/,
#   which/WDT
#   refuses/VBZ
#   to/TO
#   be/VB
#   any/DT
#   longer/RBR
#   entertained/VBN
#   with/IN
#   (NP illusory/NN)
#   (NP knowledge/NN)
#   ,/,
#   It/PRP
#   is/VBZ
#   ,/,
#   in/IN
#   (NP fact/NN)
#   ,/,
#   (NP a/DT call/NN)
#   to/TO
#   (NP reason/NN)
#   ,/,
#   again/RB
#   to/TO
#   undertake/VB
#   the/DT
#   most/RBS
#   laborious/JJ
#   of/IN
#   all/DT
#   tasks—that/DT
#   of/IN
#   (NP self-examination/NN)
#   ,/,
#   and/CC
#   to/TO
#   establish/VB
#   (NP a/DT tribunal/NN)
#   ,/,
#   which/WDT
#   may/MD
#   secure/VB
#   it/PRP
#   in/IN
#   its/PRP$
#   well-grounded/JJ
#   claims/NNS
#   ,/,
#   while/IN
#   it/PRP
#   pronounces/VBZ
#   against/IN
#   all/DT
#   baseless/JJ
#   assumptions/NNS
#   and/CC
#   pretensions/NNS
#   ,/,
#   not/RB
#   in/IN
#   (NP an/DT arbitrary/JJ manner/NN)
#   ,/,
#   but/CC
#   according/VBG
#   to/TO
#   its/PRP$
#   own/JJ
#   eternal/JJ
#   and/CC
#   unchangeable/JJ
#   laws/NNS
#   ./.
#   This/DT
#   tribunal/JJ
#   is/VBZ
#   (NP nothing/NN)
#   less/JJR
#   than/IN
#   the/DT
#   _Critical/JJ
#   Investigation/NNP
#   of/IN
#   Pure/NNP
#   Reason_/NNP
#   ./.)

# %%
import nltk
s = '(ROOT (S (NP (NNP Europe)) (VP (VBZ is) (PP (IN in) (NP (DT the) (JJ same) (NNS trends)))) (. .)))'
tree = nltk.tree.Tree.fromstring(s)

list_entity_relation_match = []

def traverse_tree(tree,pointer:list):
    list_valid_types = ["NNP","NNS"]

    for subtree in tree:
        if type(subtree) == nltk.tree.Tree:

            if subtree.label() in list_valid_types:
                pointer.append(subtree.pop()) 
                
            else:
                traverse_tree(subtree,pointer)
        else:
            continue



def extract_noun_relationships(sentence: str) -> list:
    noun_list = []
    ER_list = []
    word_tree = nltk.tree.Tree.fromstring(sentence)        
    traverse_tree(tree,noun_list)
    ER_list.extend([noun_list, sentence])
    return ER_list


# What to do with multiple nouns? 


extract_noun_relationships(s)

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)

# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')

# %%
from nltk import pos_tag, word_tokenize
from nltk.chunk import ne_chunk

ne_tree = ne_chunk(pos_tag(word_tokenize(text)))
print((ne_tree))

# %%
import pandas as pd
type(iob_tagged)
df = pd.DataFrame.from_records(iob_tagged)

# %%
df
