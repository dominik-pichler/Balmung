# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

# %%
##Setting Directory

# %%
## Input data directory
data_dir = "raw_input_data"
inputdirectory = Path(f"./resources/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/")
inputdirectory
# Out:
# PosixPath('resources/raw_input_data')

# %%
## Load Documents

# %%
## Dir PDF Loader
# loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[0].page_content)
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 131.15it/s]
# Number of chunks =  3
# At first, her government, under the administration of the _dogmatists_, was an absolute _despotism_. But, as the legislative continued to show traces of the ancient barbaric rule, her empire gradually broke up, and intestine wars introduced the reign of _anarchy;_ while the _sceptics_, like nomadic tribes, who hate a permanent habitation and settled mode of living, attacked from time to time those who had organized themselves into civil communities. But their number was, very happily, small; and thus they could not entirely put a stop to the exertions of those who persisted in raising new edifices, although on no settled or uniform plan. In recent times the hope dawned upon us of seeing those disputes settled, and the legitimacy of her claims established by a kind of _physiology_ of the human understanding—that of the celebrated Locke. But it was found that—although it was affirmed that this so-called queen could not refer her descent to any higher source than that of common experience, a circumstance which necessarily brought suspicion on her claims—as this _genealogy_ was incorrect, she persisted in the advancement of her claims to sovereignty. Thus metaphysics necessarily fell back into the antiquated and rotten constitution of _dogmatism_, and again became obnoxious to the contempt from which efforts had been made to save it.

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# /Users/dominikpichler/Documents/Pet_Projects/Athene
# (3, 3)
#                                                 text  \
# 0  At first, her government, under the administra...
# 1  At present, as all methods, according to the g...
# 2  For it is in reality vain to profess _indiffer...
#
#                                               source  \
# 0  resources/raw_input_data/The_critique_of_pure_...
# 1  resources/raw_input_data/The_critique_of_pure_...
# 2  resources/raw_input_data/The_critique_of_pure_...
#
#                            chunk_id
# 0  c896433f291c4fdbad27f380a6d77bba
# 1  52fb4de12ed44a38a8b940b511d83842
# 2  73068922347147f494ef37744ed6e1e4

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, model='mistral:latest')
    dfg1 = graph2Df(concepts_list)
    
    
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

    
    
    
    
    
dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
#  [
#    {
#        "node_1": "absolutdespotism",
#        "node_2": "her government",
#        "edge": "her government was an absolute despotism"
#    },
#    {
#        "node_1": "her government",
#        "node_2": "_dogmatists_",
#        "edge": "her government, under the administration of the dogmatists, was an absolute despotism"
#    },
#    {
#        "node_1": "ancient barbaric rule",
#        "node_2": "legislative",
#        "edge": "as the legislative continued to show traces of the ancient barbaric rule"
#    },
#    {
#        "node_1": "intestine wars",
#        "node_2": "reign of anarchy",
#        "edge": "intestine wars introduced the reign of anarchy"
#    },
#    {
#        "node_1": "_anarchy_",
#        "node_2": "her empire",
#        "edge": "her empire gradually broke up, and intestine wars introduced the reign of anarchy"
#    },
#    {
#        "node_1": "_sceptics_",
#        "node_2": "those who persisted in raising new edifices",
#        "edge": "but their number was small; and thus they could not entirely put a stop to the exertions of those who persisted in raising new edifices, although on no settled or uniform plan"
#    },
#    {
#        "node_1": "_sceptics_",
#        "node_2": "nomadic tribes",
#        "edge": "who hate a permanent habitation and settled mode of living"
#    },
#    {
#        "node_1": "civil communities",
#        "node_2": "_sceptics_",
#        "edge": "but their number was small; and thus they could not entirely put a stop to the exertions of those who persisted in raising new edifices"
#    },
#    {
#        "node_1": "recent times",
#        "node_2": "hope dawned upon us",
#        "edge": "but it was found that—although it was affirmed that this so-called queen could not refer her descent to any higher source than that of common experience, a circumstance which necessarily brought suspicion on her claims—as this genealogy was incorrect, she persisted in the advancement of her claims to sovereignty"
#    },
#    {
#        "node_1": "so-called queen",
#        "node_2": "her",
#        "edge": "but it was found that—although it was affirmed that this so-called queen could not refer her descent to any higher source than that of common experience, a circumstance which necessarily brought suspicion on her claims"
#    },
#    {
#        "node_1": "legitimacy of her claims",
#        "node_2": "established",
#        "edge": "the hope dawned upon us of seeing those disputes settled"
#    },
#    {
#        "node_1": "_physiology_ of the human understanding",
#        "node_2": "metaphysics",
#        "edge": "But it was found that—although it was affirmed that this so-called queen could not refer her descent to any higher source than that of common experience, a circumstance which necessarily brought suspicion on her claims—as this genealogy was incorrect, she persisted in the advancement of her claims to sovereignty. Thus metaphysics necessarily fell back into the antiquated and rotten constitution of dogmatism, and again became obnoxious to the contempt from which efforts had been made to save it"
#    },
#    {
#        "node_1": "_dogmatism_",
#        "node_2": "metaphysics",
#        "edge": "Thus metaphysics necessarily fell back into the antiquated and rotten constitution of dogmatism, and again became obnoxious to the contempt from which efforts had been made to save it"
#    }
# ] [
#    {
#        "node\_1": "_indifferentism_",
#        "node\_2": "chaos and night",
#        "edge": "is the mother of"
#    },
#    {
#        "node\_1": "_indifferentism_",
#        "node\_2": "source or prelude to",
#        "edge": "is the source of or prelude to"
#    },
#    {
#        "node\_1": "_indifferentism_",
#        "node\_2": "re-creation and reinstallation of a science",
#        "edge": "is the mother of or leads to"
#    }
# ]
#
# ERROR ### Here is the buggy response:   [
#    {
#        "node\_1": "_indifferentism_",
#        "node\_2": "chaos and night",
#        "edge": "is the mother of"
#    },
#    {
#        "node\_1": "_indifferentism_",
#        "node\_2": "source or prelude to",
#        "edge": "is the source of or prelude to"
#    },
#    {
#        "node\_1": "_indifferentism_",
#        "node\_2": "re-creation and reinstallation of a science",
#        "edge": "is the mother of or leads to"
#    }
# ]
#
#
#  [
#    {
#        "node_1": "_indifference_",
#        "node_2": "humanity",
#        "edge": "The professed indifference to inquiries related to humanity is not indifferent to humanity."
#    },
#    {
#        "node_1": "_indifference_",
#        "node_2": "illusory knowledge, baseless assumptions and pretensions",
#        "edge": "Those who profess indifference fall into metaphysical declarations which they claim to despise."
#    },
#    {
#        "node_1": "_indifferentists_",
#        "node_2": "humanity",
#        "edge": "The indifferentists, despite their pretense, have an effect on humanity."
#    },
#    {
#        "node_1": "_indifferentists_",
#        "node_2": "metaphysical declarations and propositions",
#        "edge": "Indifferentists unintentionally make metaphysical statements."
#    },
#    {
#        "node_1": "_judgement_",
#        "node_2": "age",
#        "edge": "The matured judgment of the age is causing indifference towards certain types of knowledge."
#    },
#    {
#        "node_1": "_judgement_",
#        "node_2": "reason",
#        "edge": "Reason is calling for self-examination and establishing a tribunal according to its laws."
#    },
#    {
#        "node_1": "Critical Investigation of Pure Reason",
#        "node_2": "_indifference_",
#        "edge": "The Critical Investigation of Pure Reason is a call to end indifference and establish a tribunal."
#    },
#    {
#        "node_1": "Critical Investigation of Pure Reason",
#        "node_2": "_judgement_",
#        "edge": "The Critical Investigation of Pure Reason is the tribunal that secures truth and pronounces against falsity."
#    }
# ](21, 5)
#                   node_1            node_2  \
# 0       absolutdespotism    her government
# 1         her government      _dogmatists_
# 2  ancient barbaric rule       legislative
# 3         intestine wars  reign of anarchy
# 4              _anarchy_        her empire
#
#                                                 edge  \
# 0           her government was an absolute despotism
# 1  her government, under the administration of th...
# 2  as the legislative continued to show traces of...
# 3     intestine wars introduced the reign of anarchy
# 4  her empire gradually broke up, and intestine w...
#
#                            chunk_id  count
# 0  c896433f291c4fdbad27f380a6d77bba      4
# 1  c896433f291c4fdbad27f380a6d77bba      4
# 2  c896433f291c4fdbad27f380a6d77bba      4
# 3  c896433f291c4fdbad27f380a6d77bba      4
# 4  c896433f291c4fdbad27f380a6d77bba      4

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                                           node_1          node_2  \
# 503                              so-called queen  her government
# 508                              so-called queen     metaphysics
# 517  those who persisted in raising new edifices      _sceptics_
# 524  those who persisted in raising new edifices  her government
# 529  those who persisted in raising new edifices     metaphysics
#
#                                               chunk_id  count  \
# 503  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...      2
# 508  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...      2
# 517  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...      3
# 524  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...      2
# 529  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...      2
#
#                      edge
# 503  contextual proximity
# 508  contextual proximity
# 517  contextual proximity
# 524  contextual proximity
# 529  contextual proximity

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                           node_1          node_2  \
# 0                                      _anarchy_      _sceptics_
# 1                                      _anarchy_      her empire
# 2                                      _anarchy_  her government
# 3                                      _anarchy_     metaphysics
# 4                                    _dogmatism_      _sceptics_
# ..                                           ...             ...
# 181                              so-called queen  her government
# 182                              so-called queen     metaphysics
# 183  those who persisted in raising new edifices      _sceptics_
# 184  those who persisted in raising new edifices  her government
# 185  those who persisted in raising new edifices     metaphysics
#
#                                               chunk_id  \
# 0    c896433f291c4fdbad27f380a6d77bba,c896433f291c4...
# 1                     c896433f291c4fdbad27f380a6d77bba
# 2    c896433f291c4fdbad27f380a6d77bba,c896433f291c4...
# 3    c896433f291c4fdbad27f380a6d77bba,c896433f291c4...
# 4    c896433f291c4fdbad27f380a6d77bba,c896433f291c4...
# ..                                                 ...
# 181  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...
# 182  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...
# 183  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...
# 184  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...
# 185  c896433f291c4fdbad27f380a6d77bba,c896433f291c4...
#
#                                                   edge  count
# 0                                 contextual proximity      3
# 1    her empire gradually broke up, and intestine w...      4
# 2                                 contextual proximity      2
# 3                                 contextual proximity      2
# 4                                 contextual proximity      3
# ..                                                 ...    ...
# 181                               contextual proximity      2
# 182                               contextual proximity      2
# 183                               contextual proximity      3
# 184                               contextual proximity      2
# 185                               contextual proximity      2
#
# [186 rows x 5 columns]

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (31,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/2)

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  4
# [['_anarchy_', '_physiology_ of the human understanding', '_sceptics_', 'absolutdespotism', 'ancient barbaric rule', 'civil communities', 'established', 'her', 'her empire', 'her government', 'hope dawned upon us', 'intestine wars', 'legislative', 'legitimacy of her claims', 'metaphysics', 'nomadic tribes', 'recent times', 'reign of anarchy', 'so-called queen', 'those who persisted in raising new edifices'], ['_dogmatism_'], ['_dogmatists_'], ['_indifference_', '_indifferentists_', '_judgement_', 'age', 'critical investigation of pure reason', 'humanity', 'illusory knowledge, baseless assumptions and pretensions', 'metaphysical declarations and propositions', 'reason']]

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                                  node    color  group
# 0                                           _anarchy_  #db5f57      1
# 1             _physiology_ of the human understanding  #db5f57      1
# 2                                          _sceptics_  #db5f57      1
# 3                                    absolutdespotism  #db5f57      1
# 4                               ancient barbaric rule  #db5f57      1
# 5                                   civil communities  #db5f57      1
# 6                                         established  #db5f57      1
# 7                                                 her  #db5f57      1
# 8                                          her empire  #db5f57      1
# 9                                      her government  #db5f57      1
# 10                                hope dawned upon us  #db5f57      1
# 11                                     intestine wars  #db5f57      1
# 12                                        legislative  #db5f57      1
# 13                           legitimacy of her claims  #db5f57      1
# 14                                        metaphysics  #db5f57      1
# 15                                     nomadic tribes  #db5f57      1
# 16                                       recent times  #db5f57      1
# 17                                   reign of anarchy  #db5f57      1
# 18                                    so-called queen  #db5f57      1
# 19        those who persisted in raising new edifices  #db5f57      1
# 20                                        _dogmatism_  #91db57      2
# 21                                       _dogmatists_  #57d3db      3
# 22                                     _indifference_  #a157db      4
# 23                                  _indifferentists_  #a157db      4
# 24                                        _judgement_  #a157db      4
# 25                                                age  #a157db      4
# 26              critical investigation of pure reason  #a157db      4
# 27                                           humanity  #a157db      4
# 28  illusory knowledge, baseless assumptions and p...  #a157db      4
# 29         metaphysical declarations and propositions  #a157db      4
# 30                                             reason  #a157db      4

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
pip install pyvis
# Out:
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: ipython>=5.3.0 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from pyvis) (8.8.0)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from pyvis) (3.1.2)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Downloading jsonpickle-3.0.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: networkx>=1.11 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from pyvis) (3.2.1)
# Requirement already satisfied: backcall in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (2.14.0)
# Requirement already satisfied: stack-data in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (5.8.1)
# Requirement already satisfied: pexpect>4.3 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: appnope in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from jinja2>=2.9.6->pyvis) (2.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=5.3.0->pyvis) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six in /Users/dominikpichler/.pyenv/versions/3.11.0/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Downloading jsonpickle-3.0.2-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-3.0.2 pyvis-0.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
